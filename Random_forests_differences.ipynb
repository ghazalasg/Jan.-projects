# %% [markdown]
# <a href="https://colab.research.google.com/github/ghazalasg/Jan.-projects/blob/main/Random_forests_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

housing_data=pd.read_csv('/content/sample_data/california_housing_test.csv')
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
housing_filtered=housing_data.dropna()
y=housing_filtered.median_house_value
housing_filtered.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
features= ['housing_median_age', 'total_rooms','total_bedrooms']
num_numeric = housing_filtered.select_dtypes(include=['number']).shape[1]
print(num_numeric)
X=housing_filtered[features]
# Out:
# 9

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

X_train,X_val,y_train,y_val=train_test_split(X,y,random_state=0)
model_1=RandomForestRegressor(n_estimators=50, random_state=0)
model_2=RandomForestRegressor(n_estimators=100, random_state=0)
model_3=RandomForestRegressor(n_estimators=100, criterion="absolute_error", random_state=0)
model_4=RandomForestRegressor(n_estimators=200, min_samples_split=20, random_state=0)
model_5=RandomForestRegressor(n_estimators=100, max_depth=7, random_state=0)

models=[model_1, model_2, model_3, model_4, model_5]


def model_score(model,X_t=X_train,X_v=X_val,y_t=y_train,y_v=y_val):
  model.fit(X_t,y_t)
  pred=model.predict(X_v)
  return mean_absolute_error(pred,y_v)

for i in range(len(models)):
  mae=model_score(models[i])
  print ("Model %d MAE: %d" % (i+1, mae))
# Out:
# Model 1 MAE: 80963
# Model 2 MAE: 81502
# Model 3 MAE: 80625
# Model 4 MAE: 79154
# Model 5 MAE: 78924
